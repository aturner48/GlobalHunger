# %% [markdown]
# # Importing Libraries and Datafile

# %%
import re
import sys
import json
import statsmodels.api as sm
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import itertools

df = pd.read_csv('/Users/lookingglass/AnacondaProjects/GHI vs Other Factors 2.0 - All Combined.csv')

# %% [markdown]
# # Brief Glance at Data

# %%
df.describe()
# Out:
#        Global Hunger Index 2017    Land Mass     Population        Export  \
# count                119.000000  1.190000e+02  1.190000e+02  1.190000e+02
# mean                  60.613445  7.957813e+05  5.143217e+07  4.633769e+10
# std                   33.356856  1.978274e+06  1.742650e+08  1.900613e+11
# min                   14.000000  2.040000e+03  5.919190e+05  2.000000e+07
# 25%                   30.000000  6.765500e+04  4.074138e+06  2.070500e+09
# 50%                   60.000000  2.410380e+05  1.190148e+07  7.000000e+09
# 75%                   89.000000  7.898285e+05  3.134300e+07  2.608000e+10
# max                  119.000000  1.709824e+07  1.379303e+09  1.990000e+12
#
#        GDP to Military   Labor Force  CO2 Emissions  Livestock Production  \
# count       116.000000  1.190000e+02     119.000000            119.000000
# mean          0.027215  2.350187e+07       0.025804             76.523819
# std           0.022544  8.804025e+07       0.038984             20.498750
# min           0.000900  1.440000e+05       0.000332             45.984074
# 25%           0.014975  1.684000e+06       0.003381             62.352037
# 50%           0.021250  5.443000e+06       0.012117             69.692222
# 75%           0.030600  1.330500e+07       0.034569             91.449554
# max           0.167200  8.071000e+08       0.283538            165.679630
#
#          Forest Area    GPI Rank        ...          \
# count     119.000000  116.000000        ...
# mean   -11360.320168    2.140259        ...
# std     74173.563725    0.372830        ...
# min   -506239.000000    1.520000        ...
# 25%    -13550.000000    1.895000        ...
# 50%      -153.500000    2.080000        ...
# 75%      1639.000000    2.320000        ...
# max    491947.100000    3.380000        ...
#
#        Land under cereal production (hectares)  \
# count                             1.190000e+02
# mean                              4.528702e+06
# std                               1.305006e+07
# min                               6.592593e+00
# 25%                               2.769373e+05
# 50%                               8.865491e+05
# 75%                               2.781870e+06
# max                               9.977335e+07
#
#        Food production index (2004-2006 = 100)  \
# count                               119.000000
# mean                                 96.101439
# std                                   6.722395
# min                                  80.142273
# 25%                                  91.989600
# 50%                                  95.240800
# 75%                                  99.264704
# max                                 121.217200
#
#        Crop production index (2004-2006 = 100)  \
# count                               119.000000
# mean                                 96.296283
# std                                   8.467885
# min                                  77.873913
# 25%                                  91.427087
# 50%                                  94.995217
# 75%                                  99.998400
# max                                 143.599200
#
#        Electric power consumption (kWh per capita)  \
# count                                    97.000000
# mean                                   1751.327965
# std                                    2006.510123
# min                                      34.049457
# 25%                                     400.993931
# 50%                                    1262.586495
# 75%                                    2206.794987
# max                                   14698.981730
#
#        Improved water source (% of population with access)  \
# count                                         119.000000
# mean                                           79.003485
# std                                            17.371996
# min                                            33.792308
# 25%                                            64.707609
# 50%                                            82.911538
# 75%                                            93.617308
# max                                            99.884615
#
#        School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# count                                         116.000000
# mean                                            0.933728
# std                                             0.119021
# min                                             0.532683
# 25%                                             0.873626
# 50%                                             0.972909
# 75%                                             1.012369
# max                                             1.126197
#
#        Agricultural land (% of land area)  \
# count                          119.000000
# mean                            43.258292
# std                             19.826995
# min                              0.530054
# 25%                             29.132057
# 50%                             42.105632
# 75%                             57.599940
# max                             84.401387
#
#        Access to electricity (% of population)  \
# count                               119.000000
# mean                                 66.237037
# std                                  34.666878
# min                                   3.616690
# 25%                                  33.384147
# 50%                                  78.262732
# 75%                                  98.235130
# max                                 100.000000
#
#        Droughts, floods, extreme temperatures (% of population, average 1990-2009)  \
# count                                         116.000000
# mean                                            1.455564
# std                                             2.093135
# min                                             0.000000
# 25%                                             0.117623
# 50%                                             0.625263
# 75%                                             1.822314
# max                                             9.226586
#
#        Concessional Debt
# count         101.000000
# mean           41.349524
# std            28.266413
# min             0.864200
# 25%            17.287322
# 50%            34.911004
# 75%            65.676248
# max            93.103533
#
# [8 rows x 22 columns]

# %%
df.columns
# Out:
# Index([u'Country Name', u'Global Hunger Index 2017', u'Land Mass ',
#        u'Population', u'Export', u'GDP to Military', u'Labor Force',
#        u'CO2 Emissions', u'Livestock Production', u'Forest Area', u'GPI Rank',
#        u'Oil Production', u'Reserves and related items (BoP, current US$)',
#        u'Land under cereal production (hectares)',
#        u'Food production index (2004-2006 = 100)',
#        u'Crop production index (2004-2006 = 100)',
#        u'Electric power consumption (kWh per capita)',
#        u'Improved water source (% of population with access)',
#        u'School enrollment, primary and secondary (gross), gender parity index (GPI)',
#        u'Agricultural land (% of land area)',
#        u'Access to electricity (% of population)',
#        u'Droughts, floods, extreme temperatures (% of population, average 1990-2009)',
#        u'Concessional Debt'],
#       dtype='object')

# %% [markdown]
# # Review of Nulls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 23 columns):
# Country Name                                                                   119 non-null object
# Global Hunger Index 2017                                                       119 non-null int64
# Land Mass                                                                      119 non-null int64
# Population                                                                     119 non-null int64
# Export                                                                         119 non-null int64
# GDP to Military                                                                116 non-null float64
# Labor Force                                                                    119 non-null int64
# CO2 Emissions                                                                  119 non-null float64
# Livestock Production                                                           119 non-null float64
# Forest Area                                                                    119 non-null float64
# GPI Rank                                                                       116 non-null float64
# Oil Production                                                                 119 non-null int64
# Reserves and related items (BoP, current US$)                                  115 non-null float64
# Land under cereal production (hectares)                                        119 non-null float64
# Food production index (2004-2006 = 100)                                        119 non-null float64
# Crop production index (2004-2006 = 100)                                        119 non-null float64
# Electric power consumption (kWh per capita)                                    97 non-null float64
# Improved water source (% of population with access)                            119 non-null float64
# School enrollment, primary and secondary (gross), gender parity index (GPI)    116 non-null float64
# Agricultural land (% of land area)                                             119 non-null float64
# Access to electricity (% of population)                                        119 non-null float64
# Droughts, floods, extreme temperatures (% of population, average 1990-2009)    116 non-null float64
# Concessional Debt                                                              101 non-null float64
# dtypes: float64(16), int64(6), object(1)
# memory usage: 21.5+ KB

# %% [markdown]
# # Dropping Nulls

# %%
df2=df.dropna()

# %% [markdown]
# # Review of Data Left After Removing Nulls

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 0 to 113
# Data columns (total 23 columns):
# Country Name                                                                   71 non-null object
# Global Hunger Index 2017                                                       71 non-null int64
# Land Mass                                                                      71 non-null int64
# Population                                                                     71 non-null int64
# Export                                                                         71 non-null int64
# GDP to Military                                                                71 non-null float64
# Labor Force                                                                    71 non-null int64
# CO2 Emissions                                                                  71 non-null float64
# Livestock Production                                                           71 non-null float64
# Forest Area                                                                    71 non-null float64
# GPI Rank                                                                       71 non-null float64
# Oil Production                                                                 71 non-null int64
# Reserves and related items (BoP, current US$)                                  71 non-null float64
# Land under cereal production (hectares)                                        71 non-null float64
# Food production index (2004-2006 = 100)                                        71 non-null float64
# Crop production index (2004-2006 = 100)                                        71 non-null float64
# Electric power consumption (kWh per capita)                                    71 non-null float64
# Improved water source (% of population with access)                            71 non-null float64
# School enrollment, primary and secondary (gross), gender parity index (GPI)    71 non-null float64
# Agricultural land (% of land area)                                             71 non-null float64
# Access to electricity (% of population)                                        71 non-null float64
# Droughts, floods, extreme temperatures (% of population, average 1990-2009)    71 non-null float64
# Concessional Debt                                                              71 non-null float64
# dtypes: float64(16), int64(6), object(1)
# memory usage: 13.3+ KB

# %%
df2.head()
# Out:
#    Country Name  Global Hunger Index 2017  Land Mass   Population  \
# 0        Turkey                        14      783562    80845215
# 2       Ukraine                        14      603550    44033874
# 3       Belarus                        14      207600     9549747
# 11   Montenegro                        14       13812      642550
# 14      Romania                        15      238391    21529967
#
#           Export  GDP to Military  Labor Force  CO2 Emissions  \
# 0   150200000000           0.0335     30550000       0.024230
# 2    33560000000           0.0286     18040000       0.072069
# 3    22980000000           0.0156      4381000       0.062831
# 11     370200000           0.0179       263200       0.037543
# 14   57720000000           0.0254      8979000       0.058647
#
#     Livestock Production  Forest Area        ...          \
# 0              81.633333      20369.0        ...
# 2             108.103478       3830.0        ...
# 3             108.345652       7549.0        ...
# 11             81.447778       2010.0        ...
# 14             95.622222       4905.0        ...
#
#     Land under cereal production (hectares)  \
# 0                              1.295917e+07
# 2                              1.360731e+07
# 3                              2.396696e+06
# 11                             1.981818e+03
# 14                             5.642454e+06
#
#     Food production index (2004-2006 = 100)  \
# 0                                 97.505600
# 2                                106.775652
# 3                                104.179565
# 11                                86.791111
# 14                                93.959600
#
#     Crop production index (2004-2006 = 100)  \
# 0                                 94.417600
# 2                                102.205652
# 3                                 91.222174
# 11                                91.814444
# 14                                87.325200
#
#     Electric power consumption (kWh per capita)  \
# 0                                   1828.815119
# 2                                   3421.743956
# 3                                   3362.265890
# 11                                  5639.281239
# 14                                  2368.159008
#
#     Improved water source (% of population with access)  \
# 0                                           93.823077
# 2                                           97.090909
# 3                                           99.553846
# 11                                          98.244444
# 14                                          88.146154
#
#     School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# 0                                            0.868815
# 2                                            0.997913
# 3                                            0.984776
# 11                                           1.012871
# 14                                           1.001731
#
#     Agricultural land (% of land area)  \
# 0                            51.622058
# 2                            71.581526
# 3                            44.608011
# 11                           31.813011
# 14                           62.568468
#
#     Access to electricity (% of population)  \
# 0                                 95.151783
# 2                                 96.514517
# 3                                100.000000
# 11                               100.000000
# 14                               100.000000
#
#     Droughts, floods, extreme temperatures (% of population, average 1990-2009)  \
# 0                                            0.136563
# 2                                            0.269239
# 3                                            0.021959
# 11                                           0.012174
# 14                                           0.084971
#
#     Concessional Debt
# 0            5.666581
# 2            4.373362
# 3           13.402875
# 11          22.510218
# 14           5.060093
#
# [5 rows x 23 columns]

# %%
df2.shape
# Out:
# (71, 23)

# %%
df2.describe()
# Out:
#        Global Hunger Index 2017    Land Mass     Population        Export  \
# count                 71.000000  7.100000e+01  7.100000e+01  7.100000e+01
# mean                  55.521127  1.101653e+06  7.849129e+07  6.820111e+10
# std                   29.033901  2.496184e+06  2.219111e+08  2.430058e+11
# min                   14.000000  2.040000e+03  6.425500e+05  1.636000e+08
# 25%                   31.000000  1.098840e+05  7.106267e+06  3.508500e+09
# 50%                   53.000000  3.312100e+05  2.152997e+07  1.058000e+10
# 75%                   75.500000  1.050016e+06  5.082473e+07  3.385000e+10
# max                  114.000000  1.709824e+07  1.379303e+09  1.990000e+12
#
#        GDP to Military   Labor Force  CO2 Emissions  Livestock Production  \
# count         71.00000  7.100000e+01      71.000000             71.000000
# mean           0.02559  3.613476e+07       0.021074             74.060447
# std            0.01595  1.124543e+08       0.024985             20.971300
# min            0.00230  2.632000e+05       0.000543             49.458704
# 25%            0.01555  2.773500e+06       0.004866             60.277685
# 50%            0.02070  8.805000e+06       0.013445             65.773333
# 75%            0.03085  2.309000e+07       0.027952             82.339352
# max            0.09250  8.071000e+08       0.119539            165.679630
#
#          Forest Area   GPI Rank        ...          \
# count      71.000000  71.000000        ...
# mean   -16096.960563   2.170282        ...
# std     95191.747635   0.332956        ...
# min   -506239.000000   1.520000        ...
# 25%    -31712.000000   1.940000        ...
# 50%     -1075.000000   2.140000        ...
# 75%      2638.000000   2.350000        ...
# max    491947.100000   3.220000        ...
#
#        Land under cereal production (hectares)  \
# count                             7.100000e+01
# mean                              6.997076e+06
# std                               1.646367e+07
# min                               1.968519e+02
# 25%                               5.205741e+05
# 50%                               1.280736e+06
# 75%                               7.984002e+06
# max                               9.977335e+07
#
#        Food production index (2004-2006 = 100)  \
# count                                71.000000
# mean                                 95.427312
# std                                   6.359288
# min                                  80.142273
# 25%                                  91.989600
# 50%                                  94.436800
# 75%                                  97.897096
# max                                 121.217200
#
#        Crop production index (2004-2006 = 100)  \
# count                                71.000000
# mean                                 95.386918
# std                                   8.131679
# min                                  80.162273
# 25%                                  91.050087
# 50%                                  94.012400
# 75%                                  99.757800
# max                                 143.599200
#
#        Electric power consumption (kWh per capita)  \
# count                                    71.000000
# mean                                   1331.261041
# std                                    1338.160941
# min                                      34.049457
# 25%                                     285.289574
# 50%                                     943.970821
# 75%                                    1851.296795
# max                                    5813.231824
#
#        Improved water source (% of population with access)  \
# count                                          71.000000
# mean                                           80.677138
# std                                            16.252174
# min                                            33.792308
# 25%                                            72.727227
# 50%                                            83.165385
# 75%                                            93.707692
# max                                            99.676923
#
#        School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# count                                          71.000000
# mean                                            0.948083
# std                                             0.099173
# min                                             0.668543
# 25%                                             0.899293
# 50%                                             0.978996
# 75%                                             1.013513
# max                                             1.104424
#
#        Agricultural land (% of land area)  \
# count                           71.000000
# mean                            43.784441
# std                             17.309216
# min                              3.411848
# 25%                             31.098796
# 50%                             43.380212
# 75%                             54.941857
# max                             79.823854
#
#        Access to electricity (% of population)  \
# count                                71.000000
# mean                                 73.759738
# std                                  29.486121
# min                                   8.741479
# 25%                                  47.670515
# 50%                                  86.326677
# 75%                                  97.987035
# max                                 100.000000
#
#        Droughts, floods, extreme temperatures (% of population, average 1990-2009)  \
# count                                          71.000000
# mean                                            1.384024
# std                                             1.939073
# min                                             0.000000
# 25%                                             0.134632
# 50%                                             0.597670
# 75%                                             1.547613
# max                                             7.950971
#
#        Concessional Debt
# count          71.000000
# mean           33.962375
# std            26.423250
# min             0.864200
# 25%            11.807522
# 50%            27.509304
# 75%            56.797615
# max            93.103533
#
# [8 rows x 22 columns]

# %% [markdown]
# # MULTICOLLINEARITY CHECK

# %%
df2.corr()
# indicators with more than one output above 0.15 are considered collinear
# Out:
#                                                     Global Hunger Index 2017  \
# Global Hunger Index 2017                                            1.000000
# Land Mass                                                          -0.176806
# Population                                                          0.079152
# Export                                                             -0.168259
# GDP to Military                                                     0.097606
# Labor Force                                                         0.021436
# CO2 Emissions                                                      -0.648384
# Livestock Production                                               -0.369060
# Forest Area                                                        -0.100733
# GPI Rank                                                            0.248695
# Oil Production                                                     -0.208954
# Reserves and related items (BoP, current US$)                      -0.142929
# Land under cereal production (hectares)                             0.018723
# Food production index (2004-2006 = 100)                            -0.202638
# Crop production index (2004-2006 = 100)                            -0.063833
# Electric power consumption (kWh per capita)                        -0.722982
# Improved water source (% of population with acc...                 -0.751510
# School enrollment, primary and secondary (gross...                 -0.603970
# Agricultural land (% of land area)                                 -0.091925
# Access to electricity (% of population)                            -0.771690
# Droughts, floods, extreme temperatures (% of po...                  0.366151
# Concessional Debt                                                   0.705369
#
#                                                     Land Mass   Population  \
# Global Hunger Index 2017                             -0.176806    0.079152
# Land Mass                                             1.000000    0.462448
# Population                                            0.462448    1.000000
# Export                                                0.546883    0.786038
# GDP to Military                                       0.055944    0.010606
# Labor Force                                           0.500970    0.980339
# CO2 Emissions                                         0.396992   -0.038999
# Livestock Production                                  0.038652   -0.199304
# Forest Area                                           0.078326    0.433603
# GPI Rank                                              0.289513    0.163705
# Oil Production                                        0.893673    0.304187
# Reserves and related items (BoP, current US$)         0.553407    0.788921
# Land under cereal production (hectares)               0.625554    0.951765
# Food production index (2004-2006 = 100)               0.018110   -0.083384
# Crop production index (2004-2006 = 100)              -0.064377   -0.038788
# Electric power consumption (kWh per capita)           0.332277   -0.054830
# Improved water source (% of population with acc...    0.096377    0.012424
# School enrollment, primary and secondary (gross...    0.063030   -0.063139
# Agricultural land (% of land area)                   -0.152995    0.111382
# Access to electricity (% of population)               0.137800    0.023508
# Droughts, floods, extreme temperatures (% of po...    0.122904    0.410824
# Concessional Debt                                    -0.249961   -0.087759
#
#                                                       Export  GDP to Military  \
# Global Hunger Index 2017                           -0.168259         0.097606
# Land Mass                                           0.546883         0.055944
# Population                                          0.786038         0.010606
# Export                                              1.000000        -0.043637
# GDP to Military                                    -0.043637         1.000000
# Labor Force                                         0.884193        -0.015214
# CO2 Emissions                                       0.102580         0.002779
# Livestock Production                               -0.151633        -0.085062
# Forest Area                                         0.586133         0.064055
# GPI Rank                                            0.037761         0.266108
# Oil Production                                      0.423419         0.111855
# Reserves and related items (BoP, current US$)       0.983940        -0.035971
# Land under cereal production (hectares)             0.723220         0.009225
# Food production index (2004-2006 = 100)            -0.108855        -0.143708
# Crop production index (2004-2006 = 100)            -0.077811        -0.222754
# Electric power consumption (kWh per capita)         0.101477        -0.025900
# Improved water source (% of population with acc...  0.089757         0.009154
# School enrollment, primary and secondary (gross...  0.046654        -0.151545
# Agricultural land (% of land area)                  0.048659        -0.254562
# Access to electricity (% of population)             0.159718         0.077456
# Droughts, floods, extreme temperatures (% of po...  0.380493        -0.122546
# Concessional Debt                                  -0.205223         0.019221
#
#                                                     Labor Force  \
# Global Hunger Index 2017                               0.021436
# Land Mass                                              0.500970
# Population                                             0.980339
# Export                                                 0.884193
# GDP to Military                                       -0.015214
# Labor Force                                            1.000000
# CO2 Emissions                                         -0.016647
# Livestock Production                                  -0.193322
# Forest Area                                            0.494990
# GPI Rank                                               0.114795
# Oil Production                                         0.333178
# Reserves and related items (BoP, current US$)          0.890724
# Land under cereal production (hectares)                0.918471
# Food production index (2004-2006 = 100)               -0.089482
# Crop production index (2004-2006 = 100)               -0.039444
# Electric power consumption (kWh per capita)           -0.025048
# Improved water source (% of population with acc...     0.017697
# School enrollment, primary and secondary (gross...    -0.033065
# Agricultural land (% of land area)                     0.096970
# Access to electricity (% of population)                0.046539
# Droughts, floods, extreme temperatures (% of po...     0.435692
# Concessional Debt                                     -0.102280
#
#                                                     CO2 Emissions  \
# Global Hunger Index 2017                                -0.648384
# Land Mass                                                0.396992
# Population                                              -0.038999
# Export                                                   0.102580
# GDP to Military                                          0.002779
# Labor Force                                             -0.016647
# CO2 Emissions                                            1.000000
# Livestock Production                                     0.597865
# Forest Area                                              0.157155
# GPI Rank                                                -0.001778
# Oil Production                                           0.501940
# Reserves and related items (BoP, current US$)            0.078905
# Land under cereal production (hectares)                  0.135717
# Food production index (2004-2006 = 100)                  0.439158
# Crop production index (2004-2006 = 100)                  0.136934
# Electric power consumption (kWh per capita)              0.875855
# Improved water source (% of population with acc...       0.524785
# School enrollment, primary and secondary (gross...       0.381866
# Agricultural land (% of land area)                       0.110733
# Access to electricity (% of population)                  0.549263
# Droughts, floods, extreme temperatures (% of po...      -0.281613
# Concessional Debt                                       -0.592840
#
#                                                     Livestock Production  \
# Global Hunger Index 2017                                       -0.369060
# Land Mass                                                       0.038652
# Population                                                     -0.199304
# Export                                                         -0.151633
# GDP to Military                                                -0.085062
# Labor Force                                                    -0.193322
# CO2 Emissions                                                   0.597865
# Livestock Production                                            1.000000
# Forest Area                                                     0.085432
# GPI Rank                                                       -0.129942
# Oil Production                                                  0.063117
# Reserves and related items (BoP, current US$)                  -0.143097
# Land under cereal production (hectares)                        -0.093625
# Food production index (2004-2006 = 100)                         0.724066
# Crop production index (2004-2006 = 100)                         0.372944
# Electric power consumption (kWh per capita)                     0.605532
# Improved water source (% of population with acc...              0.191314
# School enrollment, primary and secondary (gross...              0.230300
# Agricultural land (% of land area)                              0.311129
# Access to electricity (% of population)                         0.263516
# Droughts, floods, extreme temperatures (% of po...             -0.189456
# Concessional Debt                                              -0.215766
#
#                                                     Forest Area  GPI Rank  \
# Global Hunger Index 2017                              -0.100733  0.248695
# Land Mass                                              0.078326  0.289513
# Population                                             0.433603  0.163705
# Export                                                 0.586133  0.037761
# GDP to Military                                        0.064055  0.266108
# Labor Force                                            0.494990  0.114795
# CO2 Emissions                                          0.157155 -0.001778
# Livestock Production                                   0.085432 -0.129942
# Forest Area                                            1.000000  0.000460
# GPI Rank                                               0.000460  1.000000
# Oil Production                                         0.127345  0.335760
# Reserves and related items (BoP, current US$)          0.590230  0.040673
# Land under cereal production (hectares)                0.386103  0.253020
# Food production index (2004-2006 = 100)                0.107193 -0.213514
# Crop production index (2004-2006 = 100)                0.084775 -0.171592
# Electric power consumption (kWh per capita)            0.133277 -0.063079
# Improved water source (% of population with acc...     0.091912 -0.154417
# School enrollment, primary and secondary (gross...    -0.042535 -0.232764
# Agricultural land (% of land area)                     0.157496 -0.049175
# Access to electricity (% of population)                0.125218 -0.064663
# Droughts, floods, extreme temperatures (% of po...     0.324963  0.112908
# Concessional Debt                                     -0.003110  0.010616
#
#                                                           ...          \
# Global Hunger Index 2017                                  ...
# Land Mass                                                 ...
# Population                                                ...
# Export                                                    ...
# GDP to Military                                           ...
# Labor Force                                               ...
# CO2 Emissions                                             ...
# Livestock Production                                      ...
# Forest Area                                               ...
# GPI Rank                                                  ...
# Oil Production                                            ...
# Reserves and related items (BoP, current US$)             ...
# Land under cereal production (hectares)                   ...
# Food production index (2004-2006 = 100)                   ...
# Crop production index (2004-2006 = 100)                   ...
# Electric power consumption (kWh per capita)               ...
# Improved water source (% of population with acc...        ...
# School enrollment, primary and secondary (gross...        ...
# Agricultural land (% of land area)                        ...
# Access to electricity (% of population)                   ...
# Droughts, floods, extreme temperatures (% of po...        ...
# Concessional Debt                                         ...
#
#                                                     Land under cereal production (hectares)  \
# Global Hunger Index 2017                                                           0.018723
# Land Mass                                                                          0.625554
# Population                                                                         0.951765
# Export                                                                             0.723220
# GDP to Military                                                                    0.009225
# Labor Force                                                                        0.918471
# CO2 Emissions                                                                      0.135717
# Livestock Production                                                              -0.093625
# Forest Area                                                                        0.386103
# GPI Rank                                                                           0.253020
# Oil Production                                                                     0.478041
# Reserves and related items (BoP, current US$)                                      0.718497
# Land under cereal production (hectares)                                            1.000000
# Food production index (2004-2006 = 100)                                           -0.017170
# Crop production index (2004-2006 = 100)                                           -0.038568
# Electric power consumption (kWh per capita)                                        0.082895
# Improved water source (% of population with acc...                                 0.049395
# School enrollment, primary and secondary (gross...                                -0.055690
# Agricultural land (% of land area)                                                 0.120813
# Access to electricity (% of population)                                            0.045211
# Droughts, floods, extreme temperatures (% of po...                                 0.366564
# Concessional Debt                                                                 -0.151401
#
#                                                     Food production index (2004-2006 = 100)  \
# Global Hunger Index 2017                                                          -0.202638
# Land Mass                                                                          0.018110
# Population                                                                        -0.083384
# Export                                                                            -0.108855
# GDP to Military                                                                   -0.143708
# Labor Force                                                                       -0.089482
# CO2 Emissions                                                                      0.439158
# Livestock Production                                                               0.724066
# Forest Area                                                                        0.107193
# GPI Rank                                                                          -0.213514
# Oil Production                                                                    -0.016214
# Reserves and related items (BoP, current US$)                                     -0.091044
# Land under cereal production (hectares)                                           -0.017170
# Food production index (2004-2006 = 100)                                            1.000000
# Crop production index (2004-2006 = 100)                                            0.779815
# Electric power consumption (kWh per capita)                                        0.359027
# Improved water source (% of population with acc...                                 0.125796
# School enrollment, primary and secondary (gross...                                 0.180829
# Agricultural land (% of land area)                                                 0.302992
# Access to electricity (% of population)                                            0.138284
# Droughts, floods, extreme temperatures (% of po...                                -0.081252
# Concessional Debt                                                                 -0.108337
#
#                                                     Crop production index (2004-2006 = 100)  \
# Global Hunger Index 2017                                                          -0.063833
# Land Mass                                                                         -0.064377
# Population                                                                        -0.038788
# Export                                                                            -0.077811
# GDP to Military                                                                   -0.222754
# Labor Force                                                                       -0.039444
# CO2 Emissions                                                                      0.136934
# Livestock Production                                                               0.372944
# Forest Area                                                                        0.084775
# GPI Rank                                                                          -0.171592
# Oil Production                                                                    -0.143503
# Reserves and related items (BoP, current US$)                                     -0.052358
# Land under cereal production (hectares)                                           -0.038568
# Food production index (2004-2006 = 100)                                            0.779815
# Crop production index (2004-2006 = 100)                                            1.000000
# Electric power consumption (kWh per capita)                                        0.104701
# Improved water source (% of population with acc...                                -0.061301
# School enrollment, primary and secondary (gross...                                 0.139478
# Agricultural land (% of land area)                                                 0.324628
# Access to electricity (% of population)                                            0.025932
# Droughts, floods, extreme temperatures (% of po...                                 0.112664
# Concessional Debt                                                                  0.050516
#
#                                                     Electric power consumption (kWh per capita)  \
# Global Hunger Index 2017                                                              -0.722982
# Land Mass                                                                              0.332277
# Population                                                                            -0.054830
# Export                                                                                 0.101477
# GDP to Military                                                                       -0.025900
# Labor Force                                                                           -0.025048
# CO2 Emissions                                                                          0.875855
# Livestock Production                                                                   0.605532
# Forest Area                                                                            0.133277
# GPI Rank                                                                              -0.063079
# Oil Production                                                                         0.398546
# Reserves and related items (BoP, current US$)                                          0.086024
# Land under cereal production (hectares)                                                0.082895
# Food production index (2004-2006 = 100)                                                0.359027
# Crop production index (2004-2006 = 100)                                                0.104701
# Electric power consumption (kWh per capita)                                            1.000000
# Improved water source (% of population with acc...                                     0.627393
# School enrollment, primary and secondary (gross...                                     0.450032
# Agricultural land (% of land area)                                                     0.033940
# Access to electricity (% of population)                                                0.660270
# Droughts, floods, extreme temperatures (% of po...                                    -0.272153
# Concessional Debt                                                                     -0.610683
#
#                                                     Improved water source (% of population with access)  \
# Global Hunger Index 2017                                                                    -0.751510
# Land Mass                                                                                    0.096377
# Population                                                                                   0.012424
# Export                                                                                       0.089757
# GDP to Military                                                                              0.009154
# Labor Force                                                                                  0.017697
# CO2 Emissions                                                                                0.524785
# Livestock Production                                                                         0.191314
# Forest Area                                                                                  0.091912
# GPI Rank                                                                                    -0.154417
# Oil Production                                                                               0.135642
# Reserves and related items (BoP, current US$)                                                0.063717
# Land under cereal production (hectares)                                                      0.049395
# Food production index (2004-2006 = 100)                                                      0.125796
# Crop production index (2004-2006 = 100)                                                     -0.061301
# Electric power consumption (kWh per capita)                                                  0.627393
# Improved water source (% of population with acc...                                           1.000000
# School enrollment, primary and secondary (gross...                                           0.626990
# Agricultural land (% of land area)                                                          -0.075263
# Access to electricity (% of population)                                                      0.823803
# Droughts, floods, extreme temperatures (% of po...                                          -0.442294
# Concessional Debt                                                                           -0.634342
#
#                                                     School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# Global Hunger Index 2017                                                                    -0.603970
# Land Mass                                                                                    0.063030
# Population                                                                                  -0.063139
# Export                                                                                       0.046654
# GDP to Military                                                                             -0.151545
# Labor Force                                                                                 -0.033065
# CO2 Emissions                                                                                0.381866
# Livestock Production                                                                         0.230300
# Forest Area                                                                                 -0.042535
# GPI Rank                                                                                    -0.232764
# Oil Production                                                                               0.082864
# Reserves and related items (BoP, current US$)                                                0.036396
# Land under cereal production (hectares)                                                     -0.055690
# Food production index (2004-2006 = 100)                                                      0.180829
# Crop production index (2004-2006 = 100)                                                      0.139478
# Electric power consumption (kWh per capita)                                                  0.450032
# Improved water source (% of population with acc...                                           0.626990
# School enrollment, primary and secondary (gross...                                           1.000000
# Agricultural land (% of land area)                                                           0.043253
# Access to electricity (% of population)                                                      0.617734
# Droughts, floods, extreme temperatures (% of po...                                          -0.211851
# Concessional Debt                                                                           -0.506879
#
#                                                     Agricultural land (% of land area)  \
# Global Hunger Index 2017                                                     -0.091925
# Land Mass                                                                    -0.152995
# Population                                                                    0.111382
# Export                                                                        0.048659
# GDP to Military                                                              -0.254562
# Labor Force                                                                   0.096970
# CO2 Emissions                                                                 0.110733
# Livestock Production                                                          0.311129
# Forest Area                                                                   0.157496
# GPI Rank                                                                     -0.049175
# Oil Production                                                               -0.170956
# Reserves and related items (BoP, current US$)                                 0.045828
# Land under cereal production (hectares)                                       0.120813
# Food production index (2004-2006 = 100)                                       0.302992
# Crop production index (2004-2006 = 100)                                       0.324628
# Electric power consumption (kWh per capita)                                   0.033940
# Improved water source (% of population with acc...                           -0.075263
# School enrollment, primary and secondary (gross...                            0.043253
# Agricultural land (% of land area)                                            1.000000
# Access to electricity (% of population)                                      -0.000539
# Droughts, floods, extreme temperatures (% of po...                            0.033396
# Concessional Debt                                                            -0.125752
#
#                                                     Access to electricity (% of population)  \
# Global Hunger Index 2017                                                          -0.771690
# Land Mass                                                                          0.137800
# Population                                                                         0.023508
# Export                                                                             0.159718
# GDP to Military                                                                    0.077456
# Labor Force                                                                        0.046539
# CO2 Emissions                                                                      0.549263
# Livestock Production                                                               0.263516
# Forest Area                                                                        0.125218
# GPI Rank                                                                          -0.064663
# Oil Production                                                                     0.208527
# Reserves and related items (BoP, current US$)                                      0.129301
# Land under cereal production (hectares)                                            0.045211
# Food production index (2004-2006 = 100)                                            0.138284
# Crop production index (2004-2006 = 100)                                            0.025932
# Electric power consumption (kWh per capita)                                        0.660270
# Improved water source (% of population with acc...                                 0.823803
# School enrollment, primary and secondary (gross...                                 0.617734
# Agricultural land (% of land area)                                                -0.000539
# Access to electricity (% of population)                                            1.000000
# Droughts, floods, extreme temperatures (% of po...                                -0.363035
# Concessional Debt                                                                 -0.716806
#
#                                                     Droughts, floods, extreme temperatures (% of population, average 1990-2009)  \
# Global Hunger Index 2017                                                                     0.366151
# Land Mass                                                                                    0.122904
# Population                                                                                   0.410824
# Export                                                                                       0.380493
# GDP to Military                                                                             -0.122546
# Labor Force                                                                                  0.435692
# CO2 Emissions                                                                               -0.281613
# Livestock Production                                                                        -0.189456
# Forest Area                                                                                  0.324963
# GPI Rank                                                                                     0.112908
# Oil Production                                                                               0.000997
# Reserves and related items (BoP, current US$)                                                0.398634
# Land under cereal production (hectares)                                                      0.366564
# Food production index (2004-2006 = 100)                                                     -0.081252
# Crop production index (2004-2006 = 100)                                                      0.112664
# Electric power consumption (kWh per capita)                                                 -0.272153
# Improved water source (% of population with acc...                                          -0.442294
# School enrollment, primary and secondary (gross...                                          -0.211851
# Agricultural land (% of land area)                                                           0.033396
# Access to electricity (% of population)                                                     -0.363035
# Droughts, floods, extreme temperatures (% of po...                                           1.000000
# Concessional Debt                                                                            0.374873
#
#                                                     Concessional Debt
# Global Hunger Index 2017                                     0.705369
# Land Mass                                                   -0.249961
# Population                                                  -0.087759
# Export                                                      -0.205223
# GDP to Military                                              0.019221
# Labor Force                                                 -0.102280
# CO2 Emissions                                               -0.592840
# Livestock Production                                        -0.215766
# Forest Area                                                 -0.003110
# GPI Rank                                                     0.010616
# Oil Production                                              -0.337588
# Reserves and related items (BoP, current US$)               -0.168430
# Land under cereal production (hectares)                     -0.151401
# Food production index (2004-2006 = 100)                     -0.108337
# Crop production index (2004-2006 = 100)                      0.050516
# Electric power consumption (kWh per capita)                 -0.610683
# Improved water source (% of population with acc...          -0.634342
# School enrollment, primary and secondary (gross...          -0.506879
# Agricultural land (% of land area)                          -0.125752
# Access to electricity (% of population)                     -0.716806
# Droughts, floods, extreme temperatures (% of po...           0.374873
# Concessional Debt                                            1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# # Multiple Regression Analysis

# %%
y = df2["Global Hunger Index 2017"]
x = df2[['Land Mass ','Population', 'Export', 'GDP to Military',
       'Labor Force', 'CO2 Emissions', 'Livestock Production', 'Forest Area', 'GPI Rank', 'Oil Production',
       'Reserves and related items (BoP, current US$)',
       'Land under cereal production (hectares)',
       'Crop production index (2004-2006 = 100)',
                'Food production index (2004-2006 = 100)',
                'Concessional Debt',
       'Electric power consumption (kWh per capita)',
       'Improved water source (% of population with access)',
       'School enrollment, primary and secondary (gross), gender parity index (GPI)',
       'Agricultural land (% of land area)',
       'Access to electricity (% of population)', 'Droughts, floods, extreme temperatures (% of population, average 1990-2009)']]

model = sm.OLS(y, x).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Global Hunger Index 2017   R-squared:                       0.960
# Model:                                  OLS   Adj. R-squared:                  0.943
# Method:                       Least Squares   F-statistic:                     56.86
# Date:                      Wed, 23 May 2018   Prob (F-statistic):           8.64e-28
# Time:                              23:13:43   Log-Likelihood:                -280.31
# No. Observations:                        71   AIC:                             602.6
# Df Residuals:                            50   BIC:                             650.1
# Df Model:                                21
# Covariance Type:                  nonrobust
# ===============================================================================================================================================
#                                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------
# Land Mass                                                                    8.817e-08   3.58e-06      0.025      0.980   -7.11e-06    7.28e-06
# Population                                                                   7.655e-08   1.68e-07      0.456      0.651   -2.61e-07    4.14e-07
# Export                                                                      -1.119e-11   4.77e-11     -0.235      0.815   -1.07e-10    8.46e-11
# GDP to Military                                                                33.1512    131.346      0.252      0.802    -230.664     296.967
# Labor Force                                                                  8.707e-08   4.12e-07      0.211      0.833    -7.4e-07    9.14e-07
# CO2 Emissions                                                                -209.4735    187.843     -1.115      0.270    -586.768     167.821
# Livestock Production                                                           -0.3049      0.182     -1.680      0.099      -0.670       0.060
# Forest Area                                                                  1.669e-05   3.93e-05      0.425      0.673   -6.22e-05    9.56e-05
# GPI Rank                                                                       16.2998      6.184      2.636      0.011       3.879      28.721
# Oil Production                                                               2.662e-06   3.96e-06      0.672      0.505   -5.29e-06    1.06e-05
# Reserves and related items (BoP, current US$)                               -8.863e-10   1.36e-09     -0.651      0.518   -3.62e-09    1.85e-09
# Land under cereal production (hectares)                                      -9.93e-07   9.51e-07     -1.044      0.301    -2.9e-06    9.17e-07
# Crop production index (2004-2006 = 100)                                        -0.8436      0.473     -1.782      0.081      -1.794       0.107
# Food production index (2004-2006 = 100)                                         1.8645      0.627      2.972      0.005       0.604       3.125
# Concessional Debt                                                               0.2223      0.123      1.807      0.077      -0.025       0.469
# Electric power consumption (kWh per capita)                                    -0.0003      0.004     -0.079      0.937      -0.008       0.007
# Improved water source (% of population with access)                            -0.5056      0.263     -1.926      0.060      -1.033       0.022
# School enrollment, primary and secondary (gross), gender parity index (GPI)    -1.9851     25.275     -0.079      0.938     -52.752      48.782
# Agricultural land (% of land area)                                             -0.0301      0.138     -0.218      0.828      -0.307       0.247
# Access to electricity (% of population)                                        -0.2094      0.139     -1.505      0.139      -0.489       0.070
# Droughts, floods, extreme temperatures (% of population, average 1990-2009)     0.6304      1.357      0.464      0.644      -2.096       3.356
# ==============================================================================
# Omnibus:                        0.780   Durbin-Watson:                   1.413
# Prob(Omnibus):                  0.677   Jarque-Bera (JB):                0.574
# Skew:                           0.220   Prob(JB):                        0.751
# Kurtosis:                       2.985   Cond. No.                     2.67e+13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.67e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import seaborn as sns

f, ax = plt.subplots(figsize=(10, 8))
corr = df2.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
plt.show()

# %% [markdown]
# # Search for multicollinearity among narrowed list of indicators

# %% [markdown]
# ## Indicators with lowest p-values
# * Livestock Production
# * GPI Rank
# * Land under cereal production (hectares)
# * Food Production Index (2004-2006 = 100)
# * Access to electricity (% of population)

# %% [markdown]
# ## Creating a subset to identify and analyze the six indicators

# %%
df3 = df2[['Country Name','Land under cereal production (hectares)','Access to electricity (% of population)', 'GPI Rank','Food production index (2004-2006 = 100)',
'Livestock Production']]

# %%
df3.head()
# Out:
#    Country Name  Land under cereal production (hectares)  \
# 0        Turkey                             1.295917e+07
# 2       Ukraine                             1.360731e+07
# 3       Belarus                             2.396696e+06
# 11   Montenegro                             1.981818e+03
# 14      Romania                             5.642454e+06
#
#     Access to electricity (% of population)  GPI Rank  \
# 0                                 95.151783      2.48
# 2                                 96.514517      2.43
# 3                                100.000000      2.15
# 11                               100.000000      1.97
# 14                               100.000000      1.63
#
#     Food production index (2004-2006 = 100)  Livestock Production
# 0                                 97.505600             81.633333
# 2                                106.775652            108.103478
# 3                                104.179565            108.345652
# 11                                86.791111             81.447778
# 14                                93.959600             95.622222

# %%
df3.describe()
# Out:
#        Land under cereal production (hectares)  \
# count                             7.100000e+01
# mean                              6.997076e+06
# std                               1.646367e+07
# min                               1.968519e+02
# 25%                               5.205741e+05
# 50%                               1.280736e+06
# 75%                               7.984002e+06
# max                               9.977335e+07
#
#        Access to electricity (% of population)   GPI Rank  \
# count                                71.000000  71.000000
# mean                                 73.759738   2.170282
# std                                  29.486121   0.332956
# min                                   8.741479   1.520000
# 25%                                  47.670515   1.940000
# 50%                                  86.326677   2.140000
# 75%                                  97.987035   2.350000
# max                                 100.000000   3.220000
#
#        Food production index (2004-2006 = 100)  Livestock Production
# count                                71.000000             71.000000
# mean                                 95.427312             74.060447
# std                                   6.359288             20.971300
# min                                  80.142273             49.458704
# 25%                                  91.989600             60.277685
# 50%                                  94.436800             65.773333
# 75%                                  97.897096             82.339352
# max                                 121.217200            165.679630

# %% [markdown]
# ## Search for multicollinearity

# %%
df3.corr()
# indicators with more than one output above 0.15 are considered collinear
# Out:
#                                          Land under cereal production (hectares)  \
# Land under cereal production (hectares)                                 1.000000
# Access to electricity (% of population)                                 0.045211
# GPI Rank                                                                0.253020
# Food production index (2004-2006 = 100)                                -0.017170
# Livestock Production                                                   -0.093625
#
#                                          Access to electricity (% of population)  \
# Land under cereal production (hectares)                                 0.045211
# Access to electricity (% of population)                                 1.000000
# GPI Rank                                                               -0.064663
# Food production index (2004-2006 = 100)                                 0.138284
# Livestock Production                                                    0.263516
#
#                                          GPI Rank  \
# Land under cereal production (hectares)  0.253020
# Access to electricity (% of population) -0.064663
# GPI Rank                                 1.000000
# Food production index (2004-2006 = 100) -0.213514
# Livestock Production                    -0.129942
#
#                                          Food production index (2004-2006 = 100)  \
# Land under cereal production (hectares)                                -0.017170
# Access to electricity (% of population)                                 0.138284
# GPI Rank                                                               -0.213514
# Food production index (2004-2006 = 100)                                 1.000000
# Livestock Production                                                    0.724066
#
#                                          Livestock Production
# Land under cereal production (hectares)             -0.093625
# Access to electricity (% of population)              0.263516
# GPI Rank                                            -0.129942
# Food production index (2004-2006 = 100)              0.724066
# Livestock Production                                 1.000000

# %%
y = df2["GPI Rank"]
x = df2[['Land under cereal production (hectares)']]
model = sm.OLS(y, x).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               GPI Rank   R-squared:                       0.180
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     15.35
# Date:                Wed, 02 May 2018   Prob (F-statistic):           0.000206
# Time:                        09:22:32   Log-Likelihood:                -149.54
# No. Observations:                  71   AIC:                             301.1
# Df Residuals:                      70   BIC:                             303.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Land under cereal production (hectares)  5.235e-08   1.34e-08      3.917      0.000    2.57e-08     7.9e-08
# ==============================================================================
# Omnibus:                       93.022   Durbin-Watson:                   0.333
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1249.675
# Skew:                          -4.072   Prob(JB):                    4.33e-272
# Kurtosis:                      21.871   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.heatmap(df3.corr(), annot=False, linewidths= .5) 
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.show();

# %% [markdown]
# # Observations

# %% [markdown]
# Removing collinear indicators we're left with the following:
# * Global Peace Index -- 0.004
# * Food Production Index (2004-2006 = 100) -- 0.002
# * Access to electricity (% of population)

# %% [markdown]
# # Possible Confounders

# %%
y = df2["Improved water source (% of population with access)"]
x = df2[["Droughts, floods, extreme temperatures (% of population, average 1990-2009)"]]
model = sm.OLS(y, x).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                              OLS Regression Results
# ===============================================================================================================
# Dep. Variable:     Improved water source (% of population with access)   R-squared:                       0.252
# Model:                                                             OLS   Adj. R-squared:                  0.241
# Method:                                                  Least Squares   F-statistic:                     23.57
# Date:                                                 Wed, 02 May 2018   Prob (F-statistic):           7.07e-06
# Time:                                                         09:22:32   Log-Likelihood:                -403.56
# No. Observations:                                                   71   AIC:                             809.1
# Df Residuals:                                                       70   BIC:                             811.4
# Df Model:                                                            1
# Covariance Type:                                             nonrobust
# ===============================================================================================================================================
#                                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------
# Droughts, floods, extreme temperatures (% of population, average 1990-2009)    17.4150      3.587      4.855      0.000      10.261      24.569
# ==============================================================================
# Omnibus:                       26.140   Durbin-Watson:                   0.524
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.162
# Skew:                          -1.548   Prob(JB):                     5.17e-09
# Kurtosis:                       4.821   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y = df2["Food production index (2004-2006 = 100)"]
x = df2[["Improved water source (% of population with access)"]]
model = sm.OLS(y, x).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     Food production index (2004-2006 = 100)   R-squared:                       0.961
# Model:                                                 OLS   Adj. R-squared:                  0.960
# Method:                                      Least Squares   F-statistic:                     1703.
# Date:                                     Wed, 02 May 2018   Prob (F-statistic):           7.18e-51
# Time:                                             09:22:32   Log-Likelihood:                -309.80
# No. Observations:                                       71   AIC:                             621.6
# Df Residuals:                                           70   BIC:                             623.9
# Df Model:                                                1
# Covariance Type:                                 nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Improved water source (% of population with access)     1.1392      0.028     41.273      0.000       1.084       1.194
# ==============================================================================
# Omnibus:                       13.951   Durbin-Watson:                   1.203
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.302
# Skew:                           1.092   Prob(JB):                     0.000476
# Kurtosis:                       3.638   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y = df2['GPI Rank']
x = df2[["Food production index (2004-2006 = 100)"]]
model = sm.OLS(y, x).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               GPI Rank   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     2179.
# Date:                Wed, 02 May 2018   Prob (F-statistic):           1.75e-54
# Time:                        09:33:27   Log-Likelihood:                -33.396
# No. Observations:                  71   AIC:                             68.79
# Df Residuals:                      70   BIC:                             71.05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Food production index (2004-2006 = 100)     0.0226      0.000     46.681      0.000       0.022       0.024
# ==============================================================================
# Omnibus:                        9.516   Durbin-Watson:                   1.654
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               12.600
# Skew:                           0.535   Prob(JB):                      0.00184
# Kurtosis:                       4.764   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
